# %%
import pandas as pd
import numpy as np
import matplotlib .pyplot as plt
import seaborn as sns
import scipy.stats as stats
import statsmodels.api as sm
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv('../data/housing.csv')
print (df)
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
#        population  households  median_income  median_house_value  \
# 0           322.0       126.0         8.3252            452600.0
# 1          2401.0      1138.0         8.3014            358500.0
# 2           496.0       177.0         7.2574            352100.0
# 3           558.0       219.0         5.6431            341300.0
# 4           565.0       259.0         3.8462            342200.0
# ...           ...         ...            ...                 ...
# 20635       845.0       330.0         1.5603             78100.0
# 20636       356.0       114.0         2.5568             77100.0
# 20637      1007.0       433.0         1.7000             92300.0
# 20638       741.0       349.0         1.8672             84700.0
# 20639      1387.0       530.0         2.3886             89400.0
#
#       ocean_proximity
# 0            NEAR BAY
# 1            NEAR BAY
# 2            NEAR BAY
# 3            NEAR BAY
# 4            NEAR BAY
# ...               ...
# 20635          INLAND
# 20636          INLAND
# 20637          INLAND
# 20638          INLAND
# 20639          INLAND
#
# [20640 rows x 10 columns]

# %%
df.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
# 2    -122.24     37.85                52.0       1467.0           190.0
# 3    -122.25     37.85                52.0       1274.0           235.0
# 4    -122.25     37.85                52.0       1627.0           280.0
#
#    population  households  median_income  median_house_value ocean_proximity
# 0       322.0       126.0         8.3252            452600.0        NEAR BAY
# 1      2401.0      1138.0         8.3014            358500.0        NEAR BAY
# 2       496.0       177.0         7.2574            352100.0        NEAR BAY
# 3       558.0       219.0         5.6431            341300.0        NEAR BAY
# 4       565.0       259.0         3.8462            342200.0        NEAR BAY

# %%
df.columns
# Out:
# Index(['longitude', 'latitude', 'housing_median_age', 'total_rooms',
#        'total_bedrooms', 'population', 'households', 'median_income',
#        'median_house_value', 'ocean_proximity'],
#       dtype='str')

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           20640 non-null  float64
#  1   latitude            20640 non-null  float64
#  2   housing_median_age  20640 non-null  float64
#  3   total_rooms         20640 non-null  float64
#  4   total_bedrooms      20433 non-null  float64
#  5   population          20640 non-null  float64
#  6   households          20640 non-null  float64
#  7   median_income       20640 non-null  float64
#  8   median_house_value  20640 non-null  float64
#  9   ocean_proximity     20640 non-null  str
# dtypes: float64(9), str(1)
# memory usage: 1.6 MB

# %%
df.shape
# Out:
# (20640, 10)

# %%
df["ocean_proximity"].unique()
# Out:
# <StringArray>
# ['NEAR BAY', '<1H OCEAN', 'INLAND', 'NEAR OCEAN', 'ISLAND']
# Length: 5, dtype: str

# %%
# Missing Data Analysis
missing_values = df.isnull().sum()
missing_values_percentage = (missing_values/len(df))*100
print("Missing values \n", missing_values)
print("Missing values percentage \n", missing_values_percentage)
# Out:
# Missing values
#  longitude               0
# latitude                0
# housing_median_age      0
# total_rooms             0
# total_bedrooms        207
# population              0
# households              0
# median_income           0
# median_house_value      0
# ocean_proximity         0
# dtype: int64
# Missing values percentage
#  longitude             0.000000
# latitude              0.000000
# housing_median_age    0.000000
# total_rooms           0.000000
# total_bedrooms        1.002907
# population            0.000000
# households            0.000000
# median_income         0.000000
# median_house_value    0.000000
# ocean_proximity       0.000000
# dtype: float64

# %%
# Remove rows with missing values
data_cleaned = df.dropna()

print("\nMissing values in each column after removal:")
print(data_cleaned.isnull().sum())
# Out:
# Missing values in each column after removal:
# longitude             0
# latitude              0
# housing_median_age    0
# total_rooms           0
# total_bedrooms        0
# population            0
# households            0
# median_income         0
# median_house_value    0
# ocean_proximity       0
# dtype: int64

# %%
df.describe()
# Out:
#           longitude      latitude  housing_median_age   total_rooms  \
# count  20640.000000  20640.000000        20640.000000  20640.000000
# mean    -119.569704     35.631861           28.639486   2635.763081
# std        2.003532      2.135952           12.585558   2181.615252
# min     -124.350000     32.540000            1.000000      2.000000
# 25%     -121.800000     33.930000           18.000000   1447.750000
# 50%     -118.490000     34.260000           29.000000   2127.000000
# 75%     -118.010000     37.710000           37.000000   3148.000000
# max     -114.310000     41.950000           52.000000  39320.000000
#
#        total_bedrooms    population    households  median_income  \
# count    20433.000000  20640.000000  20640.000000   20640.000000
# mean       537.870553   1425.476744    499.539680       3.870671
# std        421.385070   1132.462122    382.329753       1.899822
# min          1.000000      3.000000      1.000000       0.499900
# 25%        296.000000    787.000000    280.000000       2.563400
# 50%        435.000000   1166.000000    409.000000       3.534800
# 75%        647.000000   1725.000000    605.000000       4.743250
# max       6445.000000  35682.000000   6082.000000      15.000100
#
#        median_house_value
# count        20640.000000
# mean        206855.816909
# std         115395.615874
# min          14999.000000
# 25%         119600.000000
# 50%         179700.000000
# 75%         264725.000000
# max         500001.000000

# %%
plt.figure(figsize=(10, 6))
sns.histplot(data_cleaned['median_house_value'], color='forestgreen', kde=True)
plt.title('Distribution of Median House Values')
plt.xlabel('Median House Value')
plt.ylabel('Frequency')
plt.show()

# %%
duplicate_value = df.duplicated().sum()
print('Duplicate values: ', duplicate_value)
# Out:
# Duplicate values:  0

# %%
#Removing Outliers 
Q1 = df['median_house_value'].quantile(0.25)
print(Q1)
Q3 = df['median_house_value'].quantile(0.75)
print(Q3)
IQR = Q3-Q1
lower_bound = Q1- 1.5 *IQR
upper_bound = Q3+ 1.5 *IQR
no_outlier = df[(df['median_house_value'] >= lower_bound) &(df['median_house_value'] <= upper_bound)]
print("orginal data shape", df)
print("New data shape without outliers: ", no_outlier.shape)
# Out:
# 119600.0
# 264725.0
# orginal data shape        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
#        population  households  median_income  median_house_value  \
# 0           322.0       126.0         8.3252            452600.0
# 1          2401.0      1138.0         8.3014            358500.0
# 2           496.0       177.0         7.2574            352100.0
# 3           558.0       219.0         5.6431            341300.0
# 4           565.0       259.0         3.8462            342200.0
# ...           ...         ...            ...                 ...
# 20635       845.0       330.0         1.5603             78100.0
# 20636       356.0       114.0         2.5568             77100.0
# 20637      1007.0       433.0         1.7000             92300.0
# 20638       741.0       349.0         1.8672             84700.0
# 20639      1387.0       530.0         2.3886             89400.0
#
#       ocean_proximity
# 0            NEAR BAY
# 1            NEAR BAY
# 2            NEAR BAY
# 3            NEAR BAY
# 4            NEAR BAY
# ...               ...
# 20635          INLAND
# 20636          INLAND
# 20637          INLAND
# 20638          INLAND
# 20639          INLAND
#
# [20640 rows x 10 columns]
# New data shape without outliers:  (19569, 10)

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(x=no_outlier['median_income'], color='purple')
plt.title('Outlier Analysis in Median Income')
plt.xlabel('Median Income')
plt.show()

# %%
Q1 = no_outlier['median_income'].quantile(0.25)
Q3 = no_outlier['median_income'].quantile(0.75)
IQR = Q3 - Q1
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR
no_outlier_1 = no_outlier[(no_outlier['median_income'] >= lower_bound) & (no_outlier['median_income'] <= upper_bound)]

print("Original data shape:", no_outlier.shape)
print("Data shape without outliers:", no_outlier_1.shape)
# Out:
# Original data shape: (19569, 10)
# Data shape without outliers: (19218, 10)

# %%
df = no_outlier_1

# %%
plt.figure(figsize=(12, 8))
sns.heatmap(df.corr(numeric_only=True), annot=True, cmap='Greens')
plt.title('Correlation Heatmap of Housing Data')
plt.show()

# %%
df = df.drop("total_bedrooms", axis = 1)
df.columns
# Out:
# Index(['longitude', 'latitude', 'housing_median_age', 'total_rooms',
#        'population', 'households', 'median_income', 'median_house_value',
#        'ocean_proximity'],
#       dtype='str')

# %%
for column in ['ocean_proximity']:  
    print(f"Unique values in {column}:", df[column].unique())
# Out:
# Unique values in ocean_proximity: <StringArray>
# ['NEAR BAY', '<1H OCEAN', 'INLAND', 'NEAR OCEAN', 'ISLAND']
# Length: 5, dtype: str

# %%
ocean_proximity_dummies = pd.get_dummies(df['ocean_proximity'], prefix='ocean_proximity')
df = pd.concat([df.drop("ocean_proximity", axis =1), ocean_proximity_dummies], axis=1)
ocean_proximity_dummies
# Out:
#        ocean_proximity_<1H OCEAN  ocean_proximity_INLAND  \
# 2                          False                   False
# 3                          False                   False
# 4                          False                   False
# 5                          False                   False
# 6                          False                   False
# ...                          ...                     ...
# 20635                      False                    True
# 20636                      False                    True
# 20637                      False                    True
# 20638                      False                    True
# 20639                      False                    True
#
#        ocean_proximity_ISLAND  ocean_proximity_NEAR BAY  \
# 2                       False                      True
# 3                       False                      True
# 4                       False                      True
# 5                       False                      True
# 6                       False                      True
# ...                       ...                       ...
# 20635                   False                     False
# 20636                   False                     False
# 20637                   False                     False
# 20638                   False                     False
# 20639                   False                     False
#
#        ocean_proximity_NEAR OCEAN
# 2                           False
# 3                           False
# 4                           False
# 5                           False
# 6                           False
# ...                           ...
# 20635                       False
# 20636                       False
# 20637                       False
# 20638                       False
# 20639                       False
#
# [19218 rows x 5 columns]

# %%
df.columns
# Out:
# Index(['longitude', 'latitude', 'housing_median_age', 'total_rooms',
#        'population', 'households', 'median_income', 'median_house_value',
#        'ocean_proximity_<1H OCEAN', 'ocean_proximity_INLAND',
#        'ocean_proximity_ISLAND', 'ocean_proximity_NEAR BAY',
#        'ocean_proximity_NEAR OCEAN'],
#       dtype='str')

# %%
df = df.drop("ocean_proximity_ISLAND", axis = 1)
df.columns
# Out:
# Index(['longitude', 'latitude', 'housing_median_age', 'total_rooms',
#        'population', 'households', 'median_income', 'median_house_value',
#        'ocean_proximity_<1H OCEAN', 'ocean_proximity_INLAND',
#        'ocean_proximity_NEAR BAY', 'ocean_proximity_NEAR OCEAN'],
#       dtype='str')

# %%
df.head(10)
# Out:
#     longitude  latitude  housing_median_age  total_rooms  population  \
# 2     -122.24     37.85                52.0       1467.0       496.0
# 3     -122.25     37.85                52.0       1274.0       558.0
# 4     -122.25     37.85                52.0       1627.0       565.0
# 5     -122.25     37.85                52.0        919.0       413.0
# 6     -122.25     37.84                52.0       2535.0      1094.0
# 7     -122.25     37.84                52.0       3104.0      1157.0
# 8     -122.26     37.84                42.0       2555.0      1206.0
# 9     -122.25     37.84                52.0       3549.0      1551.0
# 10    -122.26     37.85                52.0       2202.0       910.0
# 11    -122.26     37.85                52.0       3503.0      1504.0
#
#     households  median_income  median_house_value  ocean_proximity_<1H OCEAN  \
# 2        177.0         7.2574            352100.0                      False
# 3        219.0         5.6431            341300.0                      False
# 4        259.0         3.8462            342200.0                      False
# 5        193.0         4.0368            269700.0                      False
# 6        514.0         3.6591            299200.0                      False
# 7        647.0         3.1200            241400.0                      False
# 8        595.0         2.0804            226700.0                      False
# 9        714.0         3.6912            261100.0                      False
# 10       402.0         3.2031            281500.0                      False
# 11       734.0         3.2705            241800.0                      False
#
#     ocean_proximity_INLAND  ocean_proximity_NEAR BAY  \
# 2                    False                      True
# 3                    False                      True
# 4                    False                      True
# 5                    False                      True
# 6                    False                      True
# 7                    False                      True
# 8                    False                      True
# 9                    False                      True
# 10                   False                      True
# 11                   False                      True
#
#     ocean_proximity_NEAR OCEAN
# 2                        False
# 3                        False
# 4                        False
# 5                        False
# 6                        False
# 7                        False
# 8                        False
# 9                        False
# 10                       False
# 11                       False

# %%
# Splitting data into Train/Test
features = ['longitude', 'latitude', 'housing_median_age', 'total_rooms',
       'population', 'households', 'median_income',
       'ocean_proximity_<1H OCEAN', 'ocean_proximity_INLAND',
       'ocean_proximity_NEAR BAY', 'ocean_proximity_NEAR OCEAN']
target = ["median_house_value"]

X = df[features]
y = df[target]

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=1111)

print(f'Training set size: {X_train.shape[0]} samples')
print(f'Test set size: {X_test.shape[0]} samples')
# Out:
# Training set size: 15374 samples
# Test set size: 3844 samples

# %%
X_train
# Out:
#        longitude  latitude  housing_median_age  total_rooms  population  \
# 2749     -115.56     32.76                15.0       1278.0       653.0
# 19394    -120.83     37.77                20.0       1717.0      1062.0
# 16033    -122.45     37.72                51.0       2690.0      1795.0
# 9625     -120.32     37.29                 9.0        695.0       810.0
# 16130    -122.48     37.78                48.0       2835.0      1674.0
# ...          ...       ...                 ...          ...         ...
# 15199    -117.10     32.90                16.0       2994.0      1047.0
# 9522     -123.21     39.14                15.0       2235.0      1376.0
# 12495    -121.48     38.58                52.0       2501.0      1081.0
# 2886     -118.98     35.38                28.0       1171.0      1193.0
# 17933    -121.94     37.35                18.0       1922.0      1096.0
#
#        households  median_income  ocean_proximity_<1H OCEAN  \
# 2749        185.0         4.4821                      False
# 19394       401.0         1.6759                      False
# 16033       539.0         3.6581                      False
# 9625        190.0         1.6172                      False
# 16130       684.0         3.1290                      False
# ...           ...            ...                        ...
# 15199       437.0         5.1490                       True
# 9522        516.0         1.9032                       True
# 12495       708.0         1.5872                      False
# 2886        273.0         0.8639                      False
# 17933       545.0         2.3713                       True
#
#        ocean_proximity_INLAND  ocean_proximity_NEAR BAY  \
# 2749                     True                     False
# 19394                    True                     False
# 16033                   False                      True
# 9625                     True                     False
# 16130                   False                      True
# ...                       ...                       ...
# 15199                   False                     False
# 9522                    False                     False
# 12495                    True                     False
# 2886                     True                     False
# 17933                   False                     False
#
#        ocean_proximity_NEAR OCEAN
# 2749                        False
# 19394                       False
# 16033                       False
# 9625                        False
# 16130                       False
# ...                           ...
# 15199                       False
# 9522                        False
# 12495                       False
# 2886                        False
# 17933                       False
#
# [15374 rows x 11 columns]

# %%
X_train_const = sm.add_constant(X_train)
X_train_const
# Out:
#        const  longitude  latitude  housing_median_age  total_rooms  \
# 2749     1.0    -115.56     32.76                15.0       1278.0
# 19394    1.0    -120.83     37.77                20.0       1717.0
# 16033    1.0    -122.45     37.72                51.0       2690.0
# 9625     1.0    -120.32     37.29                 9.0        695.0
# 16130    1.0    -122.48     37.78                48.0       2835.0
# ...      ...        ...       ...                 ...          ...
# 15199    1.0    -117.10     32.90                16.0       2994.0
# 9522     1.0    -123.21     39.14                15.0       2235.0
# 12495    1.0    -121.48     38.58                52.0       2501.0
# 2886     1.0    -118.98     35.38                28.0       1171.0
# 17933    1.0    -121.94     37.35                18.0       1922.0
#
#        population  households  median_income  ocean_proximity_<1H OCEAN  \
# 2749        653.0       185.0         4.4821                      False
# 19394      1062.0       401.0         1.6759                      False
# 16033      1795.0       539.0         3.6581                      False
# 9625        810.0       190.0         1.6172                      False
# 16130      1674.0       684.0         3.1290                      False
# ...           ...         ...            ...                        ...
# 15199      1047.0       437.0         5.1490                       True
# 9522       1376.0       516.0         1.9032                       True
# 12495      1081.0       708.0         1.5872                      False
# 2886       1193.0       273.0         0.8639                      False
# 17933      1096.0       545.0         2.3713                       True
#
#        ocean_proximity_INLAND  ocean_proximity_NEAR BAY  \
# 2749                     True                     False
# 19394                    True                     False
# 16033                   False                      True
# 9625                     True                     False
# 16130                   False                      True
# ...                       ...                       ...
# 15199                   False                     False
# 9522                    False                     False
# 12495                    True                     False
# 2886                     True                     False
# 17933                   False                     False
#
#        ocean_proximity_NEAR OCEAN
# 2749                        False
# 19394                       False
# 16033                       False
# 9625                        False
# 16130                       False
# ...                           ...
# 15199                       False
# 9522                        False
# 12495                       False
# 2886                        False
# 17933                       False
#
# [15374 rows x 12 columns]

# %%
print(X_train_const.dtypes)
print(y_train.dtypes)
# Out:
# const                         float64
# longitude                     float64
# latitude                      float64
# housing_median_age            float64
# total_rooms                   float64
# population                    float64
# households                    float64
# median_income                 float64
# ocean_proximity_<1H OCEAN        bool
# ocean_proximity_INLAND           bool
# ocean_proximity_NEAR BAY         bool
# ocean_proximity_NEAR OCEAN       bool
# dtype: object
# median_house_value    float64
# dtype: object

# %%
X_train_const = X_train_const.astype(float)
y_train = y_train.astype(float)

# %%
model_fitted = sm.OLS(y_train, X_train_const).fit()

print(model_fitted.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:     median_house_value   R-squared:                       0.586
# Model:                            OLS   Adj. R-squared:                  0.586
# Method:                 Least Squares   F-statistic:                     1976.
# Date:                Wed, 04 Mar 2026   Prob (F-statistic):               0.00
# Time:                        15:42:48   Log-Likelihood:            -1.9080e+05
# No. Observations:               15374   AIC:                         3.816e+05
# Df Residuals:                   15362   BIC:                         3.817e+05
# Df Model:                          11
# Covariance Type:            nonrobust
# ==============================================================================================
#                                  coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------
# const                      -1.842e+06   9.36e+04    -19.683      0.000   -2.03e+06   -1.66e+06
# longitude                  -2.331e+04   1002.258    -23.260      0.000   -2.53e+04   -2.13e+04
# latitude                    -2.15e+04    986.577    -21.795      0.000   -2.34e+04   -1.96e+04
# housing_median_age           786.0483     44.881     17.514      0.000     698.077     874.020
# total_rooms                   -3.3975      0.719     -4.723      0.000      -4.808      -1.988
# population                   -31.2785      1.011    -30.940      0.000     -33.260     -29.297
# households                   123.9065      4.416     28.056      0.000     115.250     132.563
# median_income               3.604e+04    426.869     84.428      0.000    3.52e+04    3.69e+04
# ocean_proximity_<1H OCEAN   -1.37e+05   3.43e+04     -3.991      0.000   -2.04e+05   -6.97e+04
# ocean_proximity_INLAND     -1.767e+05   3.44e+04     -5.141      0.000   -2.44e+05   -1.09e+05
# ocean_proximity_NEAR BAY    -1.44e+05   3.44e+04     -4.192      0.000   -2.11e+05   -7.67e+04
# ocean_proximity_NEAR OCEAN -1.344e+05   3.43e+04     -3.916      0.000   -2.02e+05   -6.71e+04
# ==============================================================================
# Omnibus:                     3446.695   Durbin-Watson:                   2.011
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             9954.644
# Skew:                           1.175   Prob(JB):                         0.00
# Kurtosis:                       6.166   Cond. No.                     7.99e+05
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 7.99e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
# Testing 
X_test_const = sm.add_constant(X_test)

test_predictions = model_fitted.predict(X_test_const)
test_predictions
# Out:
# 7685     182623.083359
# 4279     152327.628071
# 14225    192843.366736
# 19122    223575.678828
# 20186    160214.843255
#              ...
# 8915     178607.541263
# 7326     189737.488296
# 994      193634.953951
# 336      197187.221692
# 9797     280917.551618
# Length: 3844, dtype: object

# %%
X_test_const
# Out:
#        const  longitude  latitude  housing_median_age  total_rooms  \
# 7685     1.0    -118.10     33.94                33.0        639.0
# 4279     1.0    -118.31     34.09                37.0        773.0
# 14225    1.0    -117.05     32.69                14.0       1689.0
# 19122    1.0    -122.65     38.25                23.0       4030.0
# 20186    1.0    -119.14     34.28                31.0        790.0
# ...      ...        ...       ...                 ...          ...
# 8915     1.0    -118.46     34.03                52.0        523.0
# 7326     1.0    -118.17     33.98                41.0        428.0
# 994      1.0    -121.73     37.71                12.0       5608.0
# 336      1.0    -122.17     37.74                46.0       1026.0
# 9797     1.0    -121.92     36.57                42.0       3944.0
#
#        population  households  median_income  ocean_proximity_<1H OCEAN  \
# 7685        460.0       118.0         3.1607                       True
# 4279        835.0       312.0         1.8576                       True
# 14225      1319.0       527.0         3.1600                      False
# 19122      1852.0       778.0         3.4020                       True
# 20186      1095.0       222.0         2.2500                      False
# ...           ...         ...            ...                        ...
# 8915        317.0       130.0         2.2794                       True
# 7326        585.0       139.0         3.1786                       True
# 994        2595.0      1067.0         3.9864                      False
# 336         749.0       225.0         3.0298                      False
# 9797       1374.0       598.0         4.1740                      False
#
#        ocean_proximity_INLAND  ocean_proximity_NEAR BAY  \
# 7685                    False                     False
# 4279                    False                     False
# 14225                   False                     False
# 19122                   False                     False
# 20186                   False                     False
# ...                       ...                       ...
# 8915                    False                     False
# 7326                    False                     False
# 994                      True                     False
# 336                     False                      True
# 9797                    False                     False
#
#        ocean_proximity_NEAR OCEAN
# 7685                        False
# 4279                        False
# 14225                        True
# 19122                       False
# 20186                        True
# ...                           ...
# 8915                        False
# 7326                        False
# 994                         False
# 336                         False
# 9797                         True
#
# [3844 rows x 12 columns]

# %%
# checking OLS Assumtions
#Linearity
plt.scatter(y_test, test_predictions, color = "forestgreen")
plt.xlabel('Observed Values')
plt.ylabel('Predicted Values')
plt.title('Observed vs Predicted Values on Test Data')
plt.plot(y_test, y_test, color='darkred')  
plt.show()

# %%
# Random Sample
mean_residuals = np.mean(model_fitted.resid)

print(f"The mean of the residuals is {np.round(mean_residuals,2)}")
# Out:
# The mean of the residuals is -0.0

# %%
plt.scatter(model_fitted.fittedvalues, model_fitted.resid, color = "forestgreen")
plt.axhline(y=0, color='red', linestyle='--')
plt.xlabel('Fitted Values')
plt.ylabel('Residuals')
plt.title('Residuals vs Fitted Values')
plt.show()

# %%
# Exogeneity
residuals = model_fitted.resid

for column in X_train.columns:
    corr_coefficient = np.corrcoef(X_train[column], residuals)[0, 1]
    print(f'Correlation between residuals and {column}: {np.round(corr_coefficient,2)}')
# Out:
# Correlation between residuals and longitude: 0.0
# Correlation between residuals and latitude: -0.0
# Correlation between residuals and housing_median_age: 0.0
# Correlation between residuals and total_rooms: 0.0
# Correlation between residuals and population: 0.0
# Correlation between residuals and households: 0.0
# Correlation between residuals and median_income: 0.0
# Correlation between residuals and ocean_proximity_<1H OCEAN: 0.0
# Correlation between residuals and ocean_proximity_INLAND: -0.0
# Correlation between residuals and ocean_proximity_NEAR BAY: 0.0
# Correlation between residuals and ocean_proximity_NEAR OCEAN: 0.0

# %%
plt.scatter(model_fitted.fittedvalues, model_fitted.resid, color = "forestgreen")
plt.axhline(y=0, color='red', linestyle='--')
plt.xlabel('Fitted Values')
plt.ylabel('Residuals')
plt.title('Residuals vs Fitted Values')
plt.show()

# %%
# Train/Test/Evaluation with Sklearn and standarize with standardScaler
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
from math import sqrt

lr = LinearRegression()
lr.fit(X_train_scaled, y_train)

y_pred = lr.predict(X_test_scaled)

mse = mean_squared_error(y_test, y_pred)
rmse = sqrt(mse)

print(f'RMSE on Test Set: {rmse}')
# Out:
# RMSE on Test Set: 57767.23719924989

# %%
print(y_pred)
y_test
# Out:
# [[182623.08335863]
#  [152327.62807119]
#  [192843.36673636]
#  ...
#  [193634.95395148]
#  [197187.22169172]
#  [280917.55161755]]
#        median_house_value
# 7685             189000.0
# 4279             193800.0
# 14225            143800.0
# 19122            193300.0
# 20186             75000.0
# ...                   ...
# 8915             337500.0
# 7326             132100.0
# 994              200200.0
# 336              107600.0
# 9797             394400.0
#
# [3844 rows x 1 columns]

# %%
model = LinearRegression()
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
import numpy as np

y_pred = model.predict(X_test)

mae = mean_absolute_error(y_test, y_pred)
rmse = np.sqrt(mean_squared_error(y_test, y_pred))
r2 = r2_score(y_test, y_pred)


print("Model Performance:")
print("MAE:", mae)
print("RMSE:", rmse)
print("R2 Score:", r2)
# Out:
# Model Performance:
# MAE: 43269.81777961578
# RMSE: 57767.237199249685
# R2 Score: 0.6116817577343361

# %%
from sklearn.ensemble import RandomForestRegressor

rf_model = RandomForestRegressor(random_state=42)
rf_model.fit(X_train, y_train)
# Out:
# c:\Users\Admin\OneDrive\Desktop\housepricepredictionapp\myvenv\Lib\site-packages\sklearn\base.py:1336: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# RandomForestRegressor(random_state=42)

# %%
y_pred_rf = rf_model.predict(X_test)

# %%
df.columns
# Out:
# Index(['longitude', 'latitude', 'housing_median_age', 'total_rooms',
#        'population', 'households', 'median_income', 'median_house_value',
#        'ocean_proximity_<1H OCEAN', 'ocean_proximity_INLAND',
#        'ocean_proximity_NEAR BAY', 'ocean_proximity_NEAR OCEAN'],
#       dtype='str')

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
import numpy as np

mae_rf = mean_absolute_error(y_test, y_pred_rf)
rmse_rf = np.sqrt(mean_squared_error(y_test, y_pred_rf))
r2_rf = r2_score(y_test, y_pred_rf)

print("Random Forest Performance:")
print("MAE:", mae_rf)
print("RMSE:", rmse_rf)
print("R2 Score:", r2_rf)
# Out:
# Random Forest Performance:
# MAE: 28381.3545239334
# RMSE: 41942.338519747944
# R2 Score: 0.7952943258399112

# %%
from sklearn.ensemble import GradientBoostingRegressor

gb_model = GradientBoostingRegressor(random_state=42)
gb_model.fit(X_train, y_train)
# Out:
# c:\Users\Admin\OneDrive\Desktop\housepricepredictionapp\myvenv\Lib\site-packages\sklearn\ensemble\_gb.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)  # TODO: Is this still required?
# GradientBoostingRegressor(random_state=42)

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
import numpy as np

y_pred_gb = gb_model.predict(X_test)

mae_gb = mean_absolute_error(y_test, y_pred_gb)
rmse_gb = np.sqrt(mean_squared_error(y_test, y_pred_gb))
r2_gb = r2_score(y_test, y_pred_gb)

print("Gradient Boosting Performance:")
print("MAE:", mae_gb)
print("RMSE:", rmse_gb)
print("R2 Score:", r2_gb)
# Out:
# Gradient Boosting Performance:
# MAE: 34418.38136241814
# RMSE: 48088.77443399117
# R2 Score: 0.7309010416948776

# %%
df.columns
# Out:
# Index(['longitude', 'latitude', 'housing_median_age', 'total_rooms',
#        'population', 'households', 'median_income', 'median_house_value',
#        'ocean_proximity_<1H OCEAN', 'ocean_proximity_INLAND',
#        'ocean_proximity_NEAR BAY', 'ocean_proximity_NEAR OCEAN'],
#       dtype='str')

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestRegressor

# %%
param_grid = {
    'n_estimators': [100, 200],
    'max_depth': [None, 10, 20],
    'min_samples_split': [2, 5],
    'min_samples_leaf': [1, 2]
}

# %%
from sklearn.model_selection import GridSearchCV
rf = RandomForestRegressor(random_state=1111)

grid_search = GridSearchCV(
    estimator=rf,
    param_grid=param_grid,
    cv=3,
    scoring='r2',
    n_jobs=-1,
    verbose=2
)

grid_search.fit(X_train, y_train)
# Out:
# Fitting 3 folds for each of 24 candidates, totalling 72 fits
# c:\Users\Admin\OneDrive\Desktop\housepricepredictionapp\myvenv\Lib\site-packages\sklearn\base.py:1336: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# GridSearchCV(cv=3, estimator=RandomForestRegressor(random_state=1111),
#              n_jobs=-1,
#              param_grid={'max_depth': [None, 10, 20],
#                          'min_samples_leaf': [1, 2],
#                          'min_samples_split': [2, 5],
#                          'n_estimators': [100, 200]},
#              scoring='r2', verbose=2)

# %%
print("Best Parameters:", grid_search.best_params_)
print("Best R2 Score (CV):", grid_search.best_score_)

best_rf = grid_search.best_estimator_
# Out:
# Best Parameters: {'max_depth': None, 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 200}
# Best R2 Score (CV): 0.7662570917218056

# %%
y_pred_best = best_rf.predict(X_test)

mae_best = mean_absolute_error(y_test, y_pred_best)
rmse_best = np.sqrt(mean_squared_error(y_test, y_pred_best))
r2_best = r2_score(y_test, y_pred_best)

print("Tuned Random Forest Performance:")
print("MAE:", mae_best)
print("RMSE:", rmse_best)
print("R2 Score:", r2_best)
# Out:
# Tuned Random Forest Performance:
# MAE: 28420.673392682445
# RMSE: 42101.04550800834
# R2 Score: 0.7937422098255802

# %%
from xgboost import XGBRegressor
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
import numpy as np

# %%
X_train.columns = X_train.columns.str.replace('[^A-Za-z0-9_]+', '_', regex=True)
X_test.columns = X_test.columns.str.replace('[^A-Za-z0-9_]+', '_', regex=True)

# %%
# Create XGBoost model
xgb_model = XGBRegressor(
    n_estimators=300,
    learning_rate=0.05,
    max_depth=4,
    subsample=0.8,
    colsample_bytree=0.8,
    random_state=42
)

# Train
xgb_model.fit(X_train, y_train)

# Predict
y_pred_xgb = xgb_model.predict(X_test)

# Evaluate
mae_xgb = mean_absolute_error(y_test, y_pred_xgb)
rmse_xgb = np.sqrt(mean_squared_error(y_test, y_pred_xgb))
r2_xgb = r2_score(y_test, y_pred_xgb)

print("XGBoost Results:")
print("MAE:", mae_xgb)
print("RMSE:", rmse_xgb)
print("R2 Score:", r2_xgb)
# Out:
# XGBoost Results:
# MAE: 29991.14453125
# RMSE: 43022.31755728647
# R2 Score: 0.7846165895462036

# %%
print("\nModel Comparison:")
print("Random Forest MAE:", mae_rf)
print("Gradient Boosting MAE:", mae_gb)
print("XGBoost MAE:", mae_xgb)
# Out:
# Model Comparison:
# Random Forest MAE: 28381.3545239334
# Gradient Boosting MAE: 34418.38136241814
# XGBoost MAE: 29991.14453125

# %%
from sklearn.model_selection import RandomizedSearchCV

param_grid = {
    'n_estimators': [200, 300, 400],
    'learning_rate': [0.01, 0.05, 0.1],
    'max_depth': [3, 4, 5],
    'subsample': [0.7, 0.8, 1.0],
    'colsample_bytree': [0.7, 0.8, 1.0]
}

xgb = XGBRegressor(random_state=42)

random_search_xgb = RandomizedSearchCV(
    estimator=xgb,
    param_distributions=param_grid,
    n_iter=15,
    cv=5,
    scoring='neg_mean_absolute_error',
    random_state=42,
    n_jobs=-1
)

random_search_xgb.fit(X_train, y_train)

print("Best XGBoost Parameters:", random_search_xgb.best_params_)
# Out:
# Best XGBoost Parameters: {'subsample': 0.8, 'n_estimators': 300, 'max_depth': 5, 'learning_rate': 0.1, 'colsample_bytree': 1.0}

# %%
best_xgb = random_search_xgb.best_estimator_

y_pred_tuned = best_xgb.predict(X_test)

from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
import numpy as np

mae_tuned = mean_absolute_error(y_test, y_pred_tuned)
rmse_tuned = np.sqrt(mean_squared_error(y_test, y_pred_tuned))
r2_tuned = r2_score(y_test, y_pred_tuned)

print("Tuned XGBoost:")
print("MAE:", mae_tuned)
print("RMSE:", rmse_tuned)
print("R2:", r2_tuned)
# Out:
# Tuned XGBoost:
# MAE: 26855.244140625
# RMSE: 39432.77986650193
# R2: 0.8190580010414124

# %%
import joblib

# Get best model
best_xgb = random_search_xgb.best_estimator_

# Save model
joblib.dump(best_xgb, "xgboost_house_price_model.pkl")

print("Model saved successfully!")
# Out:
# Model saved successfully!

# %%
# Load model
loaded_model = joblib.load("xgboost_house_price_model.pkl")

# Predict
sample_prediction = loaded_model.predict(X_test[:5])

print(sample_prediction)
# Out:
# [178709.6  219889.12 134732.89 220545.78 161191.6 ]

# %%
print("Loaded Model Type:", type(model))
# Out:
# Loaded Model Type: <class 'sklearn.linear_model._base.LinearRegression'>

# %%
import joblib

model = joblib.load("xgboost_house_price_model.pkl")
print(type(model))
# Out:
# <class 'xgboost.sklearn.XGBRegressor'>
